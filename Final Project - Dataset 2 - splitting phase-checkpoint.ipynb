# %% [markdown]
# # Final Project - Dataset 2 - splitting phase

# %% [markdown]
# ### Dataset Preparation (Train , Validate and Test data set)

# %% [markdown]
# ### <font color=blue>By Mei, Le Ping Tan , Student ID: M00724895</font><br>

# %% [markdown]
# Dataset downloaded from : https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# %% [markdown]
# Data downloaded on 18/03/2021

# %% [markdown]
# Source folder called source2 which comprises of COVID and Normal x-ray images

# %% [markdown]
# Split data sources into 70% Train, 15% Validation and 15% Test data. Splitted train, val and test data into folder named dataset2

# %% [markdown]
# ### Import libraries

# %%
import os
import numpy as np              #For handling arrays
import pandas as pd             # For handling data
import splitfolders #import split_folders to split train test val in ratio
import matplotlib.pyplot as plt #For Visualization

# %% [markdown]
# ### Explore original data source

# %%
data_path='source2'
categories=os.listdir(data_path)

print(categories)
# Out:
# ['COVID', 'Normal']

# %%
#Check Covid metatdata
file_name = 'COVID.metadata.xlsx'
df = pd.read_excel(file_name) #Read Excel file as a DataFrame
#Display top 5 rows to check if everything looks good
df.head(5)
# Out:
#   FILE NAME FORMAT     SIZE                                                URL
# 0   COVID-1    PNG  256*256  https://sirm.org/category/senza-categoria/covi...
# 1   COVID-2    PNG  256*256  https://sirm.org/category/senza-categoria/covi...
# 2   COVID-3    PNG  256*256  https://sirm.org/category/senza-categoria/covi...
# 3   COVID-4    PNG  256*256  https://sirm.org/category/senza-categoria/covi...
# 4   COVID-5    PNG  256*256  https://sirm.org/category/senza-categoria/covi...

# %%
count_row = df.shape[0]  # gives number of row count
count_col = df.shape[1]  # gives number of col count

print(count_row)
print(count_col)
# Out:
# 3616
# 4

# %%
df.count()
# Out:
# FILE NAME    3616
# FORMAT       3616
# SIZE         3616
# URL          3616
# dtype: int64

# %%
#Check normal metadata
file_name_1 = 'Normal.metadata.xlsx'
df_1 = pd.read_excel(file_name_1) #Read Excel file as a DataFrame
#Display top 5 rows to check if everything looks good
df_1.head(5)
# Out:
#   FILE NAME FORMAT     SIZE                                                URL
# 0  NORMAL-1    PNG  256*256  https://www.kaggle.com/c/rsna-pneumonia-detect...
# 1  NORMAL-2    PNG  256*256  https://www.kaggle.com/c/rsna-pneumonia-detect...
# 2  NORMAL-3    PNG  256*256  https://www.kaggle.com/c/rsna-pneumonia-detect...
# 3  NORMAL-4    PNG  256*256  https://www.kaggle.com/c/rsna-pneumonia-detect...
# 4  NORMAL-5    PNG  256*256  https://www.kaggle.com/c/rsna-pneumonia-detect...

# %%
count_row = df_1.shape[0]  # gives number of row count
count_col = df_1.shape[1]  # gives number of col count

print(count_row)
print(count_col)
# Out:
# 10192
# 4

# %% [markdown]
# ### Train, Val and Test set split from data source

# %% [markdown]
# Split data sources into 70% Train, 15% Validation and 15% Test data

# %%
splitfolders.ratio('source2', output="dataset2", seed=430, ratio=(.7, 0.15,0.15))
# Out:
# Copying files: 13808 files [00:29, 472.14 files/s]

# %%
#Define the dataset directory
train_path = 'dataset2/train'
test_path = 'dataset2/test'
val_path = 'dataset2/val'

x = ["COVID19", "Normal"]

y1 = [len(os.listdir(train_path + "/COVID")), len(os.listdir(train_path + "/Normal"))]
y2 = [len(os.listdir(val_path + "/COVID")), len(os.listdir(val_path + "/Normal"))]
y3 = [len(os.listdir(test_path + "/COVID")), len(os.listdir(test_path + "/Normal"))]

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 5), sharey=False)
ax1.bar(x=np.arange(len(x)), height=y1, width=0.8, color=["red", "blue"], edgecolor=["red", "blue"])
ax1.set_title("Train Set")
ax1.set_xticks(np.arange(len(x)))
ax1.set_xticklabels(x)

ax2.bar(x=np.arange(len(x)), height=y2, width=0.8, color=["red", "blue"], edgecolor=["red", "blue"])
ax2.set_title("Validation Set")
ax2.set_xticks(np.arange(len(x)))
ax2.set_xticklabels(x)

ax3.bar(x=np.arange(len(x)), height=y3, width=0.8, color=["red", "blue"], edgecolor=["red", "blue"])
ax3.set_title("Test Set")
ax3.set_xticks(np.arange(len(x)))
ax3.set_xticklabels(x)

plt.show()

#Count the images in each path of dataset
input_path='dataset2/'
# Distribution of our datasets
for _set in ['train', 'val', 'test']:
    
    n_covid = len(os.listdir(input_path + _set + '/COVID'))
    n_normal = len(os.listdir(input_path + _set + '/Normal'))
    
    print('{} set: COVID19 images: {}, Normal images: {}'.format(_set, n_covid, n_normal))
# Out:
# train set: COVID19 images: 2531, Normal images: 7134
# val set: COVID19 images: 542, Normal images: 1528
# test set: COVID19 images: 543, Normal images: 1530

# %%
#Visualise imaging of each path of dataset
fig, ax = plt.subplots(2, 3, figsize=(10, 7))
ax = ax.ravel()
plt.tight_layout()

for i, _set in enumerate(['train', 'val', 'test']):
    set_path = input_path+_set

    ax[i].imshow(plt.imread(set_path+'/COVID/'+os.listdir(set_path+'/COVID')[9]), cmap='gray')
    ax[i].set_title('{} set: COVID19'.format(_set))
    
    ax[i+3].imshow(plt.imread(set_path+'/Normal/'+os.listdir(set_path+'/Normal')[9]), cmap='gray')
    ax[i+3].set_title('{} set: Normal'.format(_set))
