# %% [markdown]
# ## Final Project - Chow(1_C&P)-small data - splitting phase

# %% [markdown]
# ## Dataset Preparation(Train , Validate and Test data set)

# %% [markdown]
# ### <font color=blue>By Mei, Le Ping Tan , Student ID: M00724895</font><br>

# %% [markdown]
# Dataset downloaded from : https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# %% [markdown]
# Data downloaded on 06/01/2021

# %% [markdown]
# Source folder was named as Chowdhury(1_C&P) which comprises of COVID and Viral Pneumonia chest x-ray images

# %% [markdown]
# Split data sources into 70% Train, 15% Validation and 15% Test data. Splitted train, val and test data into folder named dataset(1_C&P)

# %% [markdown]
# ### Import libraries

# %%
import os
import numpy as np              #For handling arrays
import pandas as pd             # For handling data
import splitfolders #import split_folders to split train test val in ratio
import matplotlib.pyplot as plt #For Visualization

# %% [markdown]
# ### Explore original data source

# %%
data_path='Chowdhury(1_C&P)'
categories=os.listdir(data_path)

print(categories)
# Out:
# ['COVID', 'Viral Pneumonia']

# %%
#Check Covid metatdata
file_name = 'COVID.metadata(1).xlsx'
df = pd.read_excel(file_name) #Read Excel file as a DataFrame
#Display top 5 rows to check if everything looks good
df.head(5)
# Out:
#   FILE NAME FORMAT     SIZE                                                URL
# 0   COVID 1    PNG  256*256  https://sirm.org/category/senza-categoria/covi...
# 1   COVID 2    PNG  256*256  https://sirm.org/category/senza-categoria/covi...
# 2   COVID 3    PNG  256*256  https://sirm.org/category/senza-categoria/covi...
# 3   COVID 4    PNG  256*256  https://sirm.org/category/senza-categoria/covi...
# 4   COVID 5    PNG  256*256  https://sirm.org/category/senza-categoria/covi...

# %%
count_row = df.shape[0]  # gives number of row count
count_col = df.shape[1]  # gives number of col count

print(count_row)
print(count_col)
# Out:
# 1199
# 4

# %%
df.count()
# Out:
# FILE NAME    1199
# FORMAT       1199
# SIZE         1199
# URL          1199
# dtype: int64

# %%
#Check normal metadata
file_name_1 = 'Viral Pneumonia.metadata(1).xlsx'
df_1 = pd.read_excel(file_name_1) #Read Excel file as a DataFrame
#Display top 5 rows to check if everything looks good
df_1.head(5)
# Out:
#            FILE NAME FORMAT       SIZE  \
# 0  Viral Pneumonia-1    PNG  1024*1024
# 1  Viral Pneumonia-2    PNG  1024*1024
# 2  Viral Pneumonia-3    PNG  1024*1024
# 3  Viral Pneumonia-4    PNG  1024*1024
# 4  Viral Pneumonia-5    PNG  1024*1024
#
#                                                  URL
# 0  https://www.kaggle.com/paultimothymooney/chest...
# 1  https://www.kaggle.com/paultimothymooney/chest...
# 2  https://www.kaggle.com/paultimothymooney/chest...
# 3  https://www.kaggle.com/paultimothymooney/chest...
# 4  https://www.kaggle.com/paultimothymooney/chest...

# %%
count_row = df_1.shape[0]  # gives number of row count
count_col = df_1.shape[1]  # gives number of col count

print(count_row)
print(count_col)
# Out:
# 1345
# 4

# %% [markdown]
# ### Train, Val and Test set split from data source

# %% [markdown]
# Split data sources into 70% Train, 15% Validation and 15% Test data

# %%
splitfolders.ratio('Chowdhury(1_C&P)', output="dataset(1_C&P)", seed=430, ratio=(.7, 0.15,0.15))
# Out:
# Copying files: 2544 files [00:28, 88.95 files/s]

# %%
# re-size all the images to this
IMAGE_SIZE = [224, 224]

# %%
#Define the dataset directory
train_path = 'dataset(1_C&P)/train'
test_path = 'dataset(1_C&P)/test'
val_path = 'dataset(1_C&P)/val'

x = ["COVID19", "Pneumonia"]

y1 = [len(os.listdir(train_path + "/COVID")), len(os.listdir(train_path + "/Viral Pneumonia"))]
y2 = [len(os.listdir(val_path + "/COVID")), len(os.listdir(val_path + "/Viral Pneumonia"))]
y3 = [len(os.listdir(test_path + "/COVID")), len(os.listdir(test_path + "/Viral Pneumonia"))]

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 5), sharey=False)
ax1.bar(x=np.arange(len(x)), height=y1, width=0.8, color=["red", "grey"], edgecolor=["red", "grey"])
ax1.set_title("Train Set")
ax1.set_xticks(np.arange(len(x)))
ax1.set_xticklabels(x)

ax2.bar(x=np.arange(len(x)), height=y2, width=0.8, color=["red", "grey"], edgecolor=["red", "grey"])
ax2.set_title("Validation Set")
ax2.set_xticks(np.arange(len(x)))
ax2.set_xticklabels(x)

ax3.bar(x=np.arange(len(x)), height=y3, width=0.8, color=["red", "grey"], edgecolor=["red", "grey"])
ax3.set_title("Test Set")
ax3.set_xticks(np.arange(len(x)))
ax3.set_xticklabels(x)

plt.show()

#Count the images in each path of dataset
input_path='dataset(1_C&P)/'
# Distribution of our datasets
for _set in ['train', 'val', 'test']:
    
    n_covid = len(os.listdir(input_path + _set + '/COVID'))
    n_ViralP = len(os.listdir(input_path + _set + '/Viral Pneumonia'))
    
    print('{} set: COVID19 images: {}, Pneumonia images: {}'.format(_set, n_covid, n_ViralP))
# Out:
# train set: COVID19 images: 839, Pneumonia images: 941
# val set: COVID19 images: 179, Pneumonia images: 201
# test set: COVID19 images: 181, Pneumonia images: 203

# %%
#Visualise imaging of each path of dataset
fig, ax = plt.subplots(2, 3, figsize=(10, 7))
ax = ax.ravel()
plt.tight_layout()

for i, _set in enumerate(['train', 'val', 'test']):
    set_path = input_path+_set

    ax[i].imshow(plt.imread(set_path+'/COVID/'+os.listdir(set_path+'/COVID')[9]), cmap='gray')
    ax[i].set_title('{} set: COVID19'.format(_set))
    
    ax[i+3].imshow(plt.imread(set_path+'/Viral Pneumonia/'+os.listdir(set_path+'/Viral Pneumonia')[9]), cmap='gray')
    ax[i+3].set_title('{} set: Pneumonia'.format(_set))
